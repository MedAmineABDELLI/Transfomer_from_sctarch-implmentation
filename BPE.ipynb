# %%
# suppose the texte is already clened then i will cod cleaning code using nltk
the_corpus = [
    "low","low","low","low","low","low" ,"lowest", "lowest", "newer", "newer" 
]

from collections import Counter

def calculate_word_paires(cleaned_corpus):
    counting_dict = Counter(cleaned_corpus)
    return counting_dict


#print(calculate_word_paires(the_corpus))


def Byte_per_encoding(clened_dict):
    tokens = {}
    index = 0
    for i , k in clened_dict.items():
        splited_string = i
        splited_string = list(i)
        
        for s in range(0,len(splited_string) - 1):
            paire = splited_string[s] + splited_string[s + 1]
            paire_frequency = k 
            tokens['token ' + str(index)] = paire
            tokens['fre '  + str(index)] = paire_frequency
            index = index + 1

    for i , k in tokens.items():
        token = i
        fre  = 0
        for token , frequency in tokens.items():
            if i == token:
                fre = fre + frequency
                print(token)
                
            
      


clened_dict = calculate_word_paires(the_corpus)
print(clened_dict)
Byte_per_encoding(clened_dict)
# Out:
# Counter({'low': 6, 'lowest': 2, 'newer': 2})
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 44
#      42 clened_dict = calculate_word_paires(the_corpus)
#      43 print(clened_dict)
# ---> 44 Byte_per_encoding(clened_dict)
#
# Cell In[44], line 35, in Byte_per_encoding(clened_dict)
#      33 for token , frequency in tokens.items():
#      34     if i == token:
# ---> 35         fre = fre + frequency
#      36         print(token)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
