# %%
# suppose the texte is already clened then i will cod cleaning code using nltk
the_corpus = [
    "low","low","low","low","low","low" ,"lowest", "lowest", "newer", "newer" 
]
def calculate_word_paires(cleaned_corpus):
    for k in enumerate(cleaned_corpus):
        word_1 = cleaned_corpus[k]
        for j in enumerate(cleaned_corpus):
            word = cleaned_corpus[k]
            
        

calculate_word_paires(the_corpus)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 13
#       8         for j in enumerate(cleaned_corpus):
#       9             word = cleaned_corpus[k]
# ---> 13 calculate_word_paires(the_corpus)
#
# Cell In[4], line 7, in calculate_word_paires(cleaned_corpus)
#       5 def calculate_word_paires(cleaned_corpus):
#       6     for k in enumerate(cleaned_corpus):
# ----> 7         word_1 = cleaned_corpus[k]
#       8         for j in enumerate(cleaned_corpus):
#       9             word = cleaned_corpus[k]
#
# TypeError: list indices must be integers or slices, not tuple
